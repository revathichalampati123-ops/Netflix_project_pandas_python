# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ganes\OneDrive\Revathi_Chalampati\amazon_prime_titles.csv")
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df.shape
# Out:
# (9668, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2083
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ---MOVIES VS TV SHOWS----

# %%
df['type'].value_counts()
# Out:
# type
# Movie      7814
# TV Show    1854
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs TV Shows")
plt.show()

# %% [markdown]
# ---TOP COUNTRIES-----

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States                    253
# India                            229
# United Kingdom                    28
# Canada                            16
# United Kingdom, United States     12
# Spain                              8
# Italy                              8
# Canada, United States              7
# United States, United Kingdom      6
# India, United States               5
# Name: count, dtype: int64

# %% [markdown]
# -----Content By Release Year---

# %%
df['release_year'].value_counts().head(10)
# Out:
# release_year
# 2021    1442
# 2020     962
# 2019     929
# 2018     623
# 2017     562
# 2016     521
# 2014     391
# 2015     378
# 2013     289
# 2011     252
# Name: count, dtype: int64

# %%
df['release_year'].value_counts().head(10).plot(kind='bar')
plt.title("Release Year Distribution")
plt.show()

# %% [markdown]
# ----Rating Analysis---

# %%
df['rating'].value_counts()
# Out:
# rating
# 13+         2117
# 16+         1547
# ALL         1268
# 18+         1243
# R           1010
# PG-13        393
# 7+           385
# PG           253
# NR           223
# TV-14        208
# TV-PG        169
# TV-NR        105
# G             93
# TV-G          81
# TV-MA         77
# TV-Y          74
# TV-Y7         39
# UNRATED       33
# NC-17          3
# AGES_18_       3
# NOT_RATE       3
# AGES_16_       2
# 16             1
# ALL_AGES       1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().plot(kind='bar')
plt.title("Rating Distribution")
plt.show()

# %% [markdown]
# ----Movie Duration Analysis----

# %%
movies = df[df['type'] == 'Movie']
movies.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# Saved and cleaned data set

# %%
df.to_csv("cleaned_amazon_prime.csv", index=False)

# %% [markdown]
# ---Count content by India---

# %%
df[df['country']=='India']
# Out:
#      show_id   type                 title         director  \
# 1         s2  Movie  Take Care Good Night     Girish Joshi
# 107     s108  Movie                Whoop!     Kreeti Gogia
# 142     s143  Movie   Wedding Cha Shinema  Saleel Kulkarni
# 178     s179  Movie              Viswasam             Siva
# 180     s181  Movie                 Virus       Aashiq Abu
# ...      ...    ...                   ...              ...
# 7505   s7506  Movie   The Priest (Telugu)  Jofin T. Chacko
# 8366   s8367  Movie            Aashiqui 2       Mohit Suri
# 8569   s8570  Movie    The Priest (Tamil)  Jofin T. Chacko
# 8825   s8826  Movie        Sunny (4K UHD)   Ranjith Sankar
# 8826   s8827  Movie                 Sunny   Ranjith Sankar
#
#                                                    cast country  \
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India
# 107                                        Abish Mathew   India
# ...

# %%
df.sort_values('release_year').head(1)
# Out:
#    show_id   type             title        director  \
# 83     s84  Movie  Within Our Gates  Oscar Micheaux
#
#                           cast country date_added  release_year rating  \
# 83  Evelyn Preer, Flo Clements     NaN        NaN          1920    13+
#
#    duration listed_in                                        description
# 83   78 min     Drama  Abandoned by her fiance, an educated negro wom...
